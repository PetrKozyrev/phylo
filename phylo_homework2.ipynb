# %%
#1. читает дерево https://www.jasondavies.com/tree-of-life/life.txt
#2. рисует это дерево псевдографикой (draw_ascii);
from Bio import Phylo
from matplotlib import pylab


tree1 = Phylo.read("/home/petr/bioinformatics/ib/R/phylo/life.txt", "newick")
Phylo.draw_ascii(tree1)
# Out:
#                              , Escherichia_coli_EDL933
#                              |
#                              | Escherichia_coli_O157_H7
#                              |
#                              , Escherichia_coli_O6
#                              |
#                              | Escherichia_coli_K12
#                              |
#                              , Shigella_flexneri_2a_2457T
#                              |
#                              | Shigella_flexneri_2a_301
#                              |
#                              , Salmonella_enterica
#                              |
#                              | Salmonella_typhi
#                              |
#                              | Salmonella_typhimurium
#                              |
#                              , Yersinia_pestis_Medievalis
#                              |
#                              , Yersinia_pestis_KIM
#                              |
# ...

# %%
# 3. рисует дерево с помощью draw;
Phylo.draw(tree1)

# %%
# 4. сохраняет изображение дерева в растровый формат (png) и векторный (svg/pdf)

(можно с помощью pylab.savefig, например) (картинки опять прислать);
Phylo.draw(tree1)
pylab.savefig("tree1.png", dpi=200)
pylab.savefig("tree1.svg")

# %%
# 5. изменяет формат на phyloxml и записывает файл (файл присылать по желанию);
tree1 = tree1.as_phyloxml()
Phylo.write([tree1, tree1, tree1], "life.xml", "phyloxml")
# Out:
# 3

# %%
#6. рисует дерево с помощью draw_graphviz в более-менее читаемом виде (хотя бы размер шрифта),
# другие улучшения по желанию
Phylo.draw_graphviz(tree1, font_size=2) 
pylab.savefig("tree1-graphviz.svg")
# Out:
# /home/petr/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/petr/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:137: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/petr/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /home/petr/anaconda3/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
# ...

# %%
#7. читает дерево
from ete3 import Tree

tree2 = Tree("/home/petr/bioinformatics/ib/R/phylo/life.txt", format=1)

# %%
#8. вырезает (функция prune) из дерева случайный набор из 42 (можно другое число)
# листьев (можно не случайный набор)
import random
random.seed(100)
ss = random.sample(tree2.get_leaf_names(), 42)
tree2.prune(ss)

# %%
#9. рисует любое (на выбор) из этих деревьев (можно оба)
#tree2.show()
tree2.render("%%inline")

# %%
#10. рисует любое (на выбор) из этих деревьев с дополнительной обработкой символов
# на узлах (в смысле нужно поменять дефолтные синие точки на что-нибудь)
from ete3 import NodeStyle

nstyle = NodeStyle()
nstyle["shape"] = "sphere"
nstyle["size"] = 10
nstyle["fgcolor"] = "darkred"

for n in tree2.traverse():
   n.set_style(nstyle)
#tree2.show
tree2.render("%%inline")
